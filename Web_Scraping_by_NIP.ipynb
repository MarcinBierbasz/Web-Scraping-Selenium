# %% [markdown]
# This project operates on public Central Statistical Office and was made only for learning purposes.
#
# Downloaded informations **were not used for any further processing**.

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np

# Selenium libraries
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
#ignoring this exceptions in main loop will allow browser to wait until elements appear on site.
ignored_exceptions = (NoSuchElementException,StaleElementReferenceException,) 

#Other libraries
import time
from datetime import datetime
import winsound

# %% [markdown]
# #### Reading data

# %%
NIP = pd.read_csv('Data/State_100_share_companies.csv')
NIP.head()
# Out:
#              NIP
# 0  899-232-12-94
# 1  526-267-51-21
# 2  701-030-31-02
# 3  701-030-24-56
# 4  657-008-13-17

# %% [markdown]
# Converting NIP numbers to list

# %%
NIP_list = list(NIP['NIP'])

# %%
print(f'There are {len(NIP_list)} companies to search.')
# Out:
# There are 143 companies to search.

# %% [markdown]
# #### Creating empty dataframe with desired column names.

# %%
columns = ['REGON','NIP','NIP_status','name','code_and_name_of_the_primary_legal_form',
           'code_and_name_of_the_specific_legal_form', 'code_and_name_of_the_ownership_form',
           'registration_authority', 'type_of_register_or_records', 'number_in_register_or_records',
           'country','voivodeship', 'county', 'commune', 'city', 'street', 'property_number',
           'apartment_number', 'postcode', 'postal_city', 'unusual_location', 'date_of_entry_in_the_register_or_records',
           'date_of_origin','date_of_commencement_of_activities', 'date_of_entry_to_REGON', 
           'date_of_activity_suspension', 'date_of_activity_resumption', 'date_of_activity_cessation',
           'date_of_deletion_from_REGON', 'date_of_the_judgment_about_bankruptcy_declaration',
           'date_of_insolvency_proceedings_ending', 'phone number', 'internal_phone_number','fax_number',
           'email', 'website_address', 'PKD_code','PKD_name'
          ]
df = pd.DataFrame(columns = columns)
df
# Out:
# Empty DataFrame
# Columns: [REGON, NIP, NIP_status, name, code_and_name_of_the_primary_legal_form, code_and_name_of_the_specific_legal_form, code_and_name_of_the_ownership_form, registration_authority, type_of_register_or_records, number_in_register_or_records, country, voivodeship, county, commune, city, street, property_number, apartment_number, postcode, postal_city, unusual_location, date_of_entry_in_the_register_or_records, date_of_origin, date_of_commencement_of_activities, date_of_entry_to_REGON, date_of_activity_suspension, date_of_activity_resumption, date_of_activity_cessation, date_of_deletion_from_REGON, date_of_the_judgment_about_bankruptcy_declaration, date_of_insolvency_proceedings_ending, phone number, internal_phone_number, fax_number, email, website_address, PKD_code, PKD_name]
# Index: []
#
# [0 rows x 38 columns]

# %% [markdown]
# #### Creating webdriver and loading website

# %%
driver = webdriver.Chrome()
driver.implicitly_wait(1)
driver.get('https://wyszukiwarkaregon.stat.gov.pl/')
driver.implicitly_wait(1)

# %% [markdown]
# #### Searching nip numbers on website and saving informations to dataframe.

# %%
start_time = datetime.now()

failed_NIP_list = [] # list for companies that weren't added to dataframe.

for index, nip_number in enumerate(NIP_list):
    
    # For each nip number, program makes up to 10 attempts to complete company information.
    # During fail it refreshes the page, wait 2 seconds and tries again.
    attempts = 0
    while attempts < 10:
        try:
            company_information = [] # list of informations about currently analized company
            
            # Waiting untill search box becomes available
            WebDriverWait(driver, 5,ignored_exceptions=ignored_exceptions)\
                        .until(EC.presence_of_element_located((By.ID, 'txtNip'))) 
            
            elem = driver.find_element(By.ID,'txtNip')  # Find the NIP search box
            elem.clear() # Clear any text in that search box
            elem.send_keys(nip_number + Keys.ENTER) # Send current nip number into search box and press enter
            
            #locating div with informations when it becomes available.
            my_div = WebDriverWait(driver, 5,ignored_exceptions=ignored_exceptions)\
                        .until(EC.presence_of_element_located((By.ID, 'divListaJednostek'))) 
            
            #Clicking link inside div, that load main table on website.
            WebDriverWait(my_div, 5,ignored_exceptions=ignored_exceptions)\
                        .until(EC.element_to_be_clickable((By.TAG_NAME, 'a'))) 
            driver.find_element(By.ID, 'divListaJednostek').find_element(By.TAG_NAME, 'a').click()

            # Locating all available tables with company informations.
            try:
                tables = driver.find_elements(By.CSS_SELECTOR,'div.left.divGroupFour')
            except:
                tables = driver.find_elements(By.CSS_SELECTOR,'div.left.divGroup')

            # Saving informations from located tables
            for table in tables:
                for row in table.find_elements(By.CSS_SELECTOR,'tr')[1:]:
                    cells = row.find_elements(By.CSS_SELECTOR,'td')
                    if cells:
                        company_information.append(cells[-1].text)

            # Clicking link that load additional table with PKD informations
            try:
                driver.find_element(By.CSS_SELECTOR,"div[id='praw_linkdzial']").click()
            except:
                driver.find_element(By.CSS_SELECTOR, "div[id='fiz_linkdzial']").click()
            # Locating loaded table with PKD informations
            try:
                WebDriverWait(driver, 5,ignored_exceptions=ignored_exceptions)\
                        .until(EC.presence_of_element_located((By.CSS_SELECTOR,'table.tabelaZbiorcza.tabelaZbiorczaPKD'))) 
                table = driver.find_element(By.CSS_SELECTOR,'table.tabelaZbiorcza.tabelaZbiorczaPKD')
            except:
                WebDriverWait(driver, 5,ignored_exceptions=ignored_exceptions)\
                        .until(EC.presence_of_element_located((By.CSS_SELECTOR,'table.tabelaZbiorcza'))) 
                table = driver.find_element(By.CSS_SELECTOR,'table.tabelaZbiorcza')
            # Saving main PKD code and name
            row_with_pkd_info = table.find_elements(By.CSS_SELECTOR,'tr')[1] #Locating row with main pkd code and name
            pkd_code = row_with_pkd_info.find_elements(By.CSS_SELECTOR,'td')[0].text
            pkd_name = row_with_pkd_info.find_elements(By.CSS_SELECTOR,'td')[1].text
            company_information += [pkd_code,pkd_name]       
            
            # Saving found informations about company as a new row in dataframe
            df.loc[len(df)] = company_information
            print(f'{index+1}. {nip_number} information was succesfully saved')  
            break
        except:
            attempts += 1
            if attempts == 10:
                failed_NIP_list.append(nip_number)
            print(f'{nip_number} fail number: {attempts}')
            driver.get('https://wyszukiwarkaregon.stat.gov.pl/')
            time.sleep(2)
            
end_time = datetime.now()
driver.quit()
winsound.Beep(440, 1000) # Sound effect to inform about the finished work
# Out:
# 1. 899-232-12-94 information was succesfully saved
# 2. 526-267-51-21 information was succesfully saved
# 3. 701-030-31-02 information was succesfully saved
# 4. 701-030-24-56 information was succesfully saved
# 5. 657-008-13-17 information was succesfully saved
# 6. 773-000-92-24 information was succesfully saved
# 7. 649-000-04-00 information was succesfully saved
# 8. 564-000-16-14 information was succesfully saved
# 9. 525-100-84-09 information was succesfully saved
# 10. 882-000-28-35 information was succesfully saved
# 11. 816-148-33-09 information was succesfully saved
# 12. 526-102-75-26 information was succesfully saved
# 13. 627-001-16-37 information was succesfully saved
# 14. 525-000-12-27 information was succesfully saved
# 15. 694-000-35-46 information was succesfully saved
# 16. 525-100-04-54 information was succesfully saved
# 17. 701-009-35-15 information was succesfully saved
# 18. 525-000-43-78 information was succesfully saved
# 19. 716-000-18-74 information was succesfully saved
# 20. 784-000-34-35 information was succesfully saved
# 21. 622-010-86-88 information was succesfully saved
# 22. 777-000-40-26 information was succesfully saved
# 23. 689-100-02-39 information was succesfully saved
# 24. 888-101-16-04 information was succesfully saved
# 25. 752-135-24-32 information was succesfully saved
# 26. 786-100-36-01 information was succesfully saved
# 27. 662-100-03-01 information was succesfully saved
# 28. 755-100-18-03 information was succesfully saved
# 29. 857-021-12-93 information was succesfully saved
# 30. 764-005-45-34 information was succesfully saved
# 31. 549-100-53-10 information was succesfully saved
# 32. 527-020-60-62 information was succesfully saved
# 33. 889-000-27-92 information was succesfully saved
# 34. 774-100-68-44 information was succesfully saved
# 35. 696-100-08-20 information was succesfully saved
# 36. 696-148-14-69 information was succesfully saved
# 37. 743-100-37-16 information was succesfully saved
# 38. 566-100-18-61 information was succesfully saved
# 39. 827-001-00-99 information was succesfully saved
# 40. 697-100-95-38 information was succesfully saved
# 41. 578-000-63-91 information was succesfully saved
# 42. 579-100-42-89 information was succesfully saved
# 43. 784-001-64-84 information was succesfully saved
# 44. 594-100-02-88 information was succesfully saved
# 45. 699-001-02-64 information was succesfully saved
# 46. 887-001-09-89 information was succesfully saved
# 47. 698-100-41-52 information was succesfully saved
# 48. 876-100-41-68 information was succesfully saved
# 49. 537-000-96-80 information was succesfully saved
# 50. 755-001-34-48 information was succesfully saved
# 51. 669-100-25-41 information was succesfully saved
# 52. 882-100-60-25 information was succesfully saved
# 53. 697-002-08-68 information was succesfully saved
# 54. 858-157-45-56 information was succesfully saved
# 55. 787-100-85-34 information was succesfully saved
# 56. 701-037-94-76 information was succesfully saved
# 57. 839-002-84-98 information was succesfully saved
# 58. 725-127-68-84 information was succesfully saved
# 59. 629-217-06-27 information was succesfully saved
# 60. 525-001-09-82 information was succesfully saved
# 61. 777-000-01-98 information was succesfully saved
# 62. 525-000-02-51 information was succesfully saved
# 63. 626-261-90-05 information was succesfully saved
# 64. 527-010-45-68 information was succesfully saved
# 65. 522-248-26-05 information was succesfully saved
# 66. 735-205-54-46 information was succesfully saved
# 67. 734-001-06-04 information was succesfully saved
# 68. 525-000-10-55 information was succesfully saved
# 69. 646-000-89-92 information was succesfully saved
# 70. 735-000-86-61 information was succesfully saved
# 71. 625-001-05-86 information was succesfully saved
# 72. 554-031-27-63 information was succesfully saved
# 73. 634-001-70-95 information was succesfully saved
# 74. 573-020-60-30 information was succesfully saved
# 75. 612-000-39-49 information was succesfully saved
# 76. 573-030-19-69 information was succesfully saved
# 77. 951-206-33-56 information was succesfully saved
# 78. 525-000-42-20 information was succesfully saved
# 79. 832-163-80-87 information was succesfully saved
# 80. 626-000-38-20 information was succesfully saved
# 683-000-34-27 fail number: 1
# 81. 683-000-34-27 information was succesfully saved
# 82. 525-000-87-03 information was succesfully saved
# 83. 525-000-03-92 information was succesfully saved
# 84. 701-009-57-09 information was succesfully saved
# 85. 701-009-57-15 information was succesfully saved
# 86. 525-000-72-01 information was succesfully saved
# 87. 525-000-72-76 information was succesfully saved
# 88. 125-000-02-37 information was succesfully saved
# 89. 525-001-11-83 information was succesfully saved
# 90. 852-060-10-81 information was succesfully saved
# 91. 724-000-23-73 information was succesfully saved
# 92. 525-000-73-13 information was succesfully saved
# 93. 724-000-38-81 information was succesfully saved
# 94. 868-000-04-85 information was succesfully saved
# 95. 789-000-17-11 information was succesfully saved
# 96. 867-000-29-91 information was succesfully saved
# 97. 954-277-99-41 information was succesfully saved
# 98. 954-277-99-35 information was succesfully saved
# 99. 522-311-31-98 information was succesfully saved
# 100. 677-177-78-76 information was succesfully saved
# 101. 527-277-34-92 information was succesfully saved
# 102. 671-010-07-02 information was succesfully saved
# 103. 584-030-44-72 information was succesfully saved
# 104. 851-020-49-64 information was succesfully saved
# 105. 583-026-99-81 information was succesfully saved
# 106. 525-001-01-14 information was succesfully saved
# 107. 586-010-43-97 information was succesfully saved
# 108. 521-041-42-65 information was succesfully saved
# 109. 542-000-33-67 information was succesfully saved
# 110. 739-050-94-93 information was succesfully saved
# 111. 675-020-00-83 information was succesfully saved
# 112. 526-025-07-42 information was succesfully saved
# 113. 521-041-42-71 information was succesfully saved
# 114. 525-000-98-03 information was succesfully saved
# 115. 929-001-13-98 information was succesfully saved
# 116. 896-000-75-83 information was succesfully saved
# 117. 777-000-65-51 information was succesfully saved
# 118. 521-041-29-87 information was succesfully saved
# 119. 525-000-93-06 information was succesfully saved
# 120. 851-001-11-94 information was succesfully saved
# 121. 754-001-33-75 information was succesfully saved
# 122. 657-023-57-95 information was succesfully saved
# 123. 712-016-58-88 information was succesfully saved
# 124. 634-002-03-12 information was succesfully saved
# 125. 725-003-27-43 information was succesfully saved
# 126. 813-001-44-47 information was succesfully saved
# 127. 669-050-59-49 information was succesfully saved
# 128. 554-031-62-93 information was succesfully saved
# 129. 584-095-60-45 information was succesfully saved
# 130. 525-288-94-93 information was succesfully saved
# 131. 526-030-01-67 information was succesfully saved
# 132. 525-000-10-90 information was succesfully saved
# 133. 883-178-85-49 information was succesfully saved
# 134. 701-089-44-97 information was succesfully saved
# 135. 774-000-30-97 information was succesfully saved
# 136. 526-274-89-66 information was succesfully saved
# 137. 527-243-20-41 information was succesfully saved
# 138. 701-021-82-99 information was succesfully saved
# 139. 661-020-01-89 information was succesfully saved
# 140. 634-000-32-71 information was succesfully saved
# 141. 573-020-61-94 information was succesfully saved
# 142. 525-000-01-27 information was succesfully saved
# 143. 526-030-02-04 information was succesfully saved

# %%
print(f"Done in {pd.to_timedelta(end_time-start_time).round('1s')}")
# Out:
# Done in 0 days 00:11:35

# %% [markdown]
# #### Checking if every company informations were added to dataframe

# %%
if (len(df) == len(NIP_list)) and not failed_NIP_list:
    print('Got informations for all companies!')
else:
    print("Warning: Couldn't add some companies information to dataframe! Fails are stored in 'failed_NIP_list' variable.")
# Out:
# Got informations for all companies!

# %% [markdown]
# #### Dataframe after main loop.

# %%
df
# Out:
#          REGON         NIP NIP_status  \
# 0    932117189  8992321294
# 1    015296322  5262675121
# 2    142989877  7010303102
# 3    142990254  7010302456
# 4    000617663  6570081317
# ..         ...         ...        ...
# 138  000617700  6610200189
# 139  000616089  6340003271
# 140  000616050  5730206194
# 141  000617166  5250000127
# 142  006746410  5260300204
#
#                                                   name  \
# 0    AMW INVEST SPÓŁKA Z OGRANICZONĄ ODPOWIEDZIALNO...
# 1    AMW TOWARZYSTWO BUDOWNICTWA SPOŁECZNEGO "KWATE...
# 2    AMW SINEVIA SPÓŁKA Z OGRANICZONĄ ODPOWIEDZIALN...
# 3    AMW REWITA SPÓŁKA Z OGRANICZONĄ ODPOWIEDZIALNO...
# 4    PRZEDSIĘBIORSTWO KOMUNIKACJI SAMOCHODOWEJ W KI...
# ..                                                 ...
# 138  PRZEDSIĘBIORSTWO KOMUNIKACJI SAMOCHODOWEJ W OS...
# 139  PRZEDSIĘBIORSTWO PRZEWOZU TOWARÓW POWSZECHNEJ ...
# 140  PRZEDSIĘBIORSTWO KOMUNIKACJI SAMOCHODOWEJ CZĘS...
# 141  PRZEDSIĘBIORSTWO KOMUNIKACJI SAMOCHODOWEJ "POL...
# 142           AGENCJA ROZWOJU PRZEMYSŁU SPÓŁKA AKCYJNA
#
#     code_and_name_of_the_primary_legal_form  \
# 0                          1 - OSOBA PRAWNA
# 1                          1 - OSOBA PRAWNA
# 2                          1 - OSOBA PRAWNA
# 3                          1 - OSOBA PRAWNA
# 4                          1 - OSOBA PRAWNA
# ..                                      ...
# 138                        1 - OSOBA PRAWNA
# 139                        1 - OSOBA PRAWNA
# 140                        1 - OSOBA PRAWNA
# 141                        1 - OSOBA PRAWNA
# 142                        1 - OSOBA PRAWNA
#
#           code_and_name_of_the_specific_legal_form  \
# 0    117 - SPÓŁKI Z OGRANICZONĄ ODPOWIEDZIALNOŚCIĄ
# 1    117 - SPÓŁKI Z OGRANICZONĄ ODPOWIEDZIALNOŚCIĄ
# 2    117 - SPÓŁKI Z OGRANICZONĄ ODPOWIEDZIALNOŚCIĄ
# 3    117 - SPÓŁKI Z OGRANICZONĄ ODPOWIEDZIALNOŚCIĄ
# 4                             116 - SPÓŁKI AKCYJNE
# ..                                             ...
# 138                           116 - SPÓŁKI AKCYJNE
# 139                           116 - SPÓŁKI AKCYJNE
# 140                           116 - SPÓŁKI AKCYJNE
# 141                           116 - SPÓŁKI AKCYJNE
# 142                           116 - SPÓŁKI AKCYJNE
#
#           code_and_name_of_the_ownership_form  \
# 0    112 - WŁASNOŚĆ PAŃSTWOWYCH OSÓB PRAWNYCH
# 1               111 - WŁASNOŚĆ SKARBU PAŃSTWA
# 2               111 - WŁASNOŚĆ SKARBU PAŃSTWA
# 3               111 - WŁASNOŚĆ SKARBU PAŃSTWA
# 4               111 - WŁASNOŚĆ SKARBU PAŃSTWA
# ..                                        ...
# 138             111 - WŁASNOŚĆ SKARBU PAŃSTWA
# 139             111 - WŁASNOŚĆ SKARBU PAŃSTWA
# 140             111 - WŁASNOŚĆ SKARBU PAŃSTWA
# 141             111 - WŁASNOŚĆ SKARBU PAŃSTWA
# 142             111 - WŁASNOŚĆ SKARBU PAŃSTWA
#
#                                 registration_authority  \
# 0    SĄD REJONOWY DLA M.ST.WARSZAWY W WARSZAWIE,XII...
# 1    SĄD REJONOWY DLA M.ST.WARSZAWY W WARSZAWIE,XII...
# 2    SĄD REJONOWY DLA M.ST.WARSZAWY W WARSZAWIE,XIV...
# 3    SĄD REJONOWY DLA M.ST.WARSZAWY W WARSZAWIE,XIV...
# 4    SĄD REJONOWY W KIELCACH, X WYDZIAŁ GOSPODARCZY...
# ..                                                 ...
# 138  SĄD REJONOWY W KIELCACH, X WYDZIAŁ GOSPODARCZY...
# 139  SĄD REJONOWY KATOWICE-WSCHÓD W KATOWICACH, VII...
# 140  SĄD REJONOWY W CZĘSTOCHOWIE, XVII WYDZIAŁ GOSP...
# 141  SĄD REJONOWY DLA M.ST.WARSZAWY W WARSZAWIE,XII...
# 142  SĄD REJONOWY DLA M.ST.WARSZAWY W WARSZAWIE,XII...
#
#     type_of_register_or_records number_in_register_or_records  ...  \
# 0       REJESTR PRZEDSIĘBIORCÓW                    0000003772  ...
# 1       REJESTR PRZEDSIĘBIORCÓW                    0000140528  ...
# 2       REJESTR PRZEDSIĘBIORCÓW                    0000392868  ...
# 3       REJESTR PRZEDSIĘBIORCÓW                    0000394569  ...
# 4       REJESTR PRZEDSIĘBIORCÓW                    0000047244  ...
# ..                          ...                           ...  ...
# 138     REJESTR PRZEDSIĘBIORCÓW                    0000050306  ...
# 139     REJESTR PRZEDSIĘBIORCÓW                    0000087670  ...
# 140     REJESTR PRZEDSIĘBIORCÓW                    0000222666  ...
# 141     REJESTR PRZEDSIĘBIORCÓW                    0000376721  ...
# 142     REJESTR PRZEDSIĘBIORCÓW                    0000037957  ...
#
#     date_of_deletion_from_REGON  \
# 0
# 1
# 2
# 3
# 4
# ..                          ...
# 138
# 139
# 140
# 141
# 142
#
#     date_of_the_judgment_about_bankruptcy_declaration  \
# 0
# 1
# 2
# 3
# 4                                          2013-10-04
# ..                                                ...
# 138
# 139
# 140
# 141
# 142
#
#     date_of_insolvency_proceedings_ending phone number internal_phone_number  \
# 0
# 1                                              6876158
# 2
# 3
# 4                                            413661500
# ..                                    ...          ...                   ...
# 138                                         0412479791
# 139                                          601422812
# 140
# 141                                            8236200
# 142
#
#      fax_number                        email      website_address PKD_code  \
# 0                                                                    7111Z
# 1       6269150      KWATERA@WTBS-KWATERA.PL                         6832Z
# 2                                                                    4299Z
# 3                                                                    5520Z
# 4     413660110            pks@pks.kielce.pl        pks.kielce.pl    4939Z
# ..          ...                          ...                  ...      ...
# 138  0412479789       zarzad@pksostrowiec.pl  www.pksostrowiec.pl    4939Z
# 139                 BIURO@PKSKATOWICE.COM.PL                         4520Z
# 140                                                                  4931Z
# 141     8236231  SEKRETARIAT@PKS.WARSZAWA.PL                         4939Z
# 142                                                                  6492Z
#
#                                               PKD_name
# 0                  DZIAŁALNOŚĆ W ZAKRESIE ARCHITEKTURY
# 1    ZARZĄDZANIE NIERUCHOMOŚCIAMI WYKONYWANE NA ZLE...
# 2    ROBOTY ZWIĄZANE Z BUDOWĄ POZOSTAŁYCH OBIEKTÓW ...
# 3    OBIEKTY NOCLEGOWE TURYSTYCZNE I MIEJSCA KRÓTKO...
# 4    POZOSTAŁY TRANSPORT LĄDOWY PASAŻERSKI, GDZIE I...
# ..                                                 ...
# 138  POZOSTAŁY TRANSPORT LĄDOWY PASAŻERSKI, GDZIE I...
# 139  KONSERWACJA I NAPRAWA POJAZDÓW SAMOCHODOWYCH, ...
# 140  TRANSPORT LĄDOWY PASAŻERSKI, MIEJSKI I PODMIEJSKI
# 141  POZOSTAŁY TRANSPORT LĄDOWY PASAŻERSKI, GDZIE I...
# 142                POZOSTAŁE FORMY UDZIELANIA KREDYTÓW
#
# [143 rows x 38 columns]

# %% [markdown]
# Saving downloaded informations in excel file.

# %%
df.to_excel('Data/Company_informations.xlsx', index = False)
